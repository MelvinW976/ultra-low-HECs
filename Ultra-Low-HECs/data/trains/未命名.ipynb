# %%
import numpy as np

# %%
p = np.load('train_x.npy')

# %%
import pandas as pd

# %%
p= pd.DataFrame(p)

# %%
p
# Out:
#        0      1    2     3        4         5         6          7   \
# 0     3.0   62.0  3.0  12.0  17.6926  212.3110  12.05210  52.666667
# 1     7.0  229.0  1.0   1.0  31.2849   31.2849  11.09230  83.000000
# 2     7.0  225.0  3.0   9.0  46.5516  418.9640   4.16578  49.111111
# 3     4.0  140.0  3.0  12.0  22.8710  274.4510   7.26211  42.666667
# 4     6.0  194.0  2.0   6.0  28.3409  170.0460  10.33890  71.000000
# ...   ...    ...  ...   ...      ...       ...       ...        ...
# 4932  3.0   62.0  2.0   8.0  26.0533  208.4260   5.32170  35.500000
# 4933  4.0  127.0  3.0   8.0  28.9976  231.9810   5.64035  41.500000
# 4934  6.0  194.0  2.0   4.0  21.9549   87.8198   4.79746  28.000000
# 4935  7.0  221.0  2.0   4.0  16.8143   67.2572  14.76030  60.000000
# 4936  6.0  194.0  2.0   8.0  23.1516  185.2130   1.79210  12.000000
#
#              8         9   ...         22          23        24          25  \
# ...
